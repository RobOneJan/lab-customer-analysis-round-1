# %%
import pandas as pd
import numpy as np

# %%
file1=pd.read_csv("file1.csv")
file2=pd.read_csv("file2.csv")
file3=pd.read_csv("file3.csv")

# %%
file1.head()
file1.reindex(sorted(file1.columns),axis=1)
file1.shape
# Out:
# (4008, 11)

# %%
file2.head()
file2.reindex(sorted(file2.columns),axis=1)
file2.shape
# Out:
# (996, 11)

# %%
file3.head()
file3.reindex(sorted(file3.columns),axis=1)
file3.shape
# Out:
# (7070, 11)

# %%
columns_names=file1.columns

# %%
data=pd.DataFrame(columns=columns_names)

# %%
data=pd.concat([data,file1,file2,file3],axis=0)
data.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount State Gender
# ...

# %%
data.shape
# Out:
# (12074, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   9137 non-null   object
#  1   ST                         2067 non-null   object
#  2   GENDER                     1945 non-null   object
#  3   Education                  9137 non-null   object
#  4   Customer Lifetime Value    9130 non-null   object
#  5   Income                     9137 non-null   float64
#  6   Monthly Premium Auto       9137 non-null   float64
#  7   Number of Open Complaints  9137 non-null   object
#  8   Policy Type                9137 non-null   object
#  9   Vehicle Class              9137 non-null   object
#  10  Total Claim Amount         9137 non-null   float64
#  11  State                      7070 non-null   object
#  12  Gender                     7070 non-null   object
# ...

# %%
data.drop(["Education","Number of Open Complaints"],axis=1,inplace=True)

# %%
data.head()
# Out:
#   Customer          ST GENDER Customer Lifetime Value   Income  \
# 0  RB50392  Washington    NaN                     NaN      0.0
# 1  QZ44356     Arizona      F              697953.59%      0.0
# 2  AI49188      Nevada      F             1288743.17%  48767.0
# 3  WW63253  California      M              764586.18%      0.0
# 4  GA49547  Washington      M              536307.65%  36357.0
#
#    Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount  \
# 0                1000.0   Personal Auto  Four-Door Car            2.704934
# 1                  94.0   Personal Auto  Four-Door Car         1131.464935
# 2                 108.0   Personal Auto   Two-Door Car          566.472247
# 3                 106.0  Corporate Auto            SUV          529.881344
# 4                  68.0   Personal Auto  Four-Door Car           17.269323
#
#   State Gender
# 0   NaN    NaN
# 1   NaN    NaN
# 2   NaN    NaN
# 3   NaN    NaN
# 4   NaN    NaN

# %%
a="23%"

print( a[:-1])
# Out:
# 23

# %%
def percentage(a):
    if a not np.nan:
        a=a[:-1]


    return a
# Out:
#   File "<ipython-input-14-86d688c217c4>", line 2
#     if a not np.nan:
#              ^
# SyntaxError: invalid syntax

# %%
#data["Customer Lifetime Value"]=list(map(percentage,data["Customer Lifetime Value"]))
data["Customer Lifetime Value"].replace({"%",""})
# Out:
# 0               NaN
# 1        697953.59%
# 2       1288743.17%
# 3        764586.18%
# 4        536307.65%
#            ...
# 7065          23406
# 7066        3096.51
# 7067        8163.89
# 7068        7524.44
# 7069        2611.84
# Name: Customer Lifetime Value, Length: 12074, dtype: object

# %%
data['Customer Lifetime Value'].replace({'%':''},regex = True)
# Out:
# 0              NaN
# 1        697953.59
# 2       1288743.17
# 3        764586.18
# 4        536307.65
#            ...
# 7065         23406
# 7066       3096.51
# 7067       8163.89
# 7068       7524.44
# 7069       2611.84
# Name: Customer Lifetime Value, Length: 12074, dtype: object

# %%
data['Customer Lifetime Value'] = [x*100 for x in data['Customer Lifetime Value']]

# %%
data.head()
# Out:
#   Customer          ST GENDER  \
# 0  RB50392  Washington    NaN
# 1  QZ44356     Arizona      F
# 2  AI49188      Nevada      F
# 3  WW63253  California      M
# 4  GA49547  Washington      M
#
#                              Customer Lifetime Value   Income  \
# 0                                                NaN      0.0
# 1  697953.59%697953.59%697953.59%697953.59%697953...      0.0
# 2  1288743.17%1288743.17%1288743.17%1288743.17%12...  48767.0
# 3  764586.18%764586.18%764586.18%764586.18%764586...      0.0
# 4  536307.65%536307.65%536307.65%536307.65%536307...  36357.0
#
#    Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount  \
# 0                1000.0   Personal Auto  Four-Door Car            2.704934
# 1                  94.0   Personal Auto  Four-Door Car         1131.464935
# 2                 108.0   Personal Auto   Two-Door Car          566.472247
# 3                 106.0  Corporate Auto            SUV          529.881344
# ...

# %%
data = data.drop_duplicates()

# %%
data[data['Income']>0]
# Out:
#      Customer          ST GENDER  \
# 2     AI49188      Nevada      F
# 4     GA49547  Washington      M
# 5     OC83172      Oregon      F
# 6     XZ87318      Oregon      F
# 8     DY87989      Oregon      M
# ...       ...         ...    ...
# 7063  TF56202         NaN    NaN
# 7064  YM19146         NaN    NaN
# 7065  LA72316         NaN    NaN
# 7066  PK87824         NaN    NaN
# 7068  UP19263         NaN    NaN
#
#                                 Customer Lifetime Value   Income  \
# 2     1288743.17%1288743.17%1288743.17%1288743.17%12...  48767.0
# 4     536307.65%536307.65%536307.65%536307.65%536307...  36357.0
# 5     825629.78%825629.78%825629.78%825629.78%825629...  62902.0
# 6     538089.86%538089.86%538089.86%538089.86%538089...  55350.0
# 8     2412750.40%2412750.40%2412750.40%2412750.40%24...  14072.0
# ...                                                 ...      ...
# 7063                                             503217  66367.0
# ...
